# %%
import pandas as pd

# %%
with open('.//ipl_csv2//all_matches.csv') as f:
          ipl_data = pd.read_csv(f)
        
ipl_data
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         match_id   season  start_date  \
# 0         335982  2007/08  2008-04-18
# 1         335982  2007/08  2008-04-18
# 2         335982  2007/08  2008-04-18
# 3         335982  2007/08  2008-04-18
# 4         335982  2007/08  2008-04-18
# ...          ...      ...         ...
# 196795   1254070     2021  2021-04-20
# 196796   1254070     2021  2021-04-20
# 196797   1254070     2021  2021-04-20
# 196798   1254070     2021  2021-04-20
# 196799   1254070     2021  2021-04-20
#
#                                            venue  innings  ball  \
# 0                          M Chinnaswamy Stadium        1   0.1
# 1                          M Chinnaswamy Stadium        1   0.2
# 2                          M Chinnaswamy Stadium        1   0.3
# 3                          M Chinnaswamy Stadium        1   0.4
# 4                          M Chinnaswamy Stadium        1   0.5
# ...                                          ...      ...   ...
# 196795  MA Chidambaram Stadium, Chepauk, Chennai        2  18.6
# 196796  MA Chidambaram Stadium, Chepauk, Chennai        2  18.7
# 196797  MA Chidambaram Stadium, Chepauk, Chennai        2  18.8
# 196798  MA Chidambaram Stadium, Chepauk, Chennai        2  19.1
# 196799  MA Chidambaram Stadium, Chepauk, Chennai        2  19.2
#
#                  batting_team                 bowling_team      striker  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# ...                       ...                          ...          ...
# 196795         Delhi Capitals               Mumbai Indians  Lalit Yadav
# 196796         Delhi Capitals               Mumbai Indians   SO Hetmyer
# 196797         Delhi Capitals               Mumbai Indians   SO Hetmyer
# 196798         Delhi Capitals               Mumbai Indians   SO Hetmyer
# 196799         Delhi Capitals               Mumbai Indians   SO Hetmyer
#
#         non_striker  ... extras  wides  noballs  byes  legbyes  penalty  \
# 0       BB McCullum  ...      1    NaN      NaN   NaN      1.0      NaN
# 1        SC Ganguly  ...      0    NaN      NaN   NaN      NaN      NaN
# 2        SC Ganguly  ...      1    1.0      NaN   NaN      NaN      NaN
# 3        SC Ganguly  ...      0    NaN      NaN   NaN      NaN      NaN
# 4        SC Ganguly  ...      0    NaN      NaN   NaN      NaN      NaN
# ...             ...  ...    ...    ...      ...   ...      ...      ...
# 196795   SO Hetmyer  ...      0    NaN      NaN   NaN      NaN      NaN
# 196796  Lalit Yadav  ...      0    NaN      NaN   NaN      NaN      NaN
# 196797  Lalit Yadav  ...      0    NaN      NaN   NaN      NaN      NaN
# 196798  Lalit Yadav  ...      0    NaN      NaN   NaN      NaN      NaN
# 196799  Lalit Yadav  ...      1    NaN      1.0   NaN      NaN      NaN
#
#         wicket_type  player_dismissed other_wicket_type other_player_dismissed
# 0               NaN               NaN               NaN                    NaN
# 1               NaN               NaN               NaN                    NaN
# 2               NaN               NaN               NaN                    NaN
# 3               NaN               NaN               NaN                    NaN
# 4               NaN               NaN               NaN                    NaN
# ...             ...               ...               ...                    ...
# 196795          NaN               NaN               NaN                    NaN
# 196796          NaN               NaN               NaN                    NaN
# 196797          NaN               NaN               NaN                    NaN
# 196798          NaN               NaN               NaN                    NaN
# 196799          NaN               NaN               NaN                    NaN
#
# [196800 rows x 22 columns]

# %%
#print all columns
print(ipl_data.columns)
# Out:
# Index(['match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes',
#        'penalty', 'wicket_type', 'player_dismissed', 'other_wicket_type',
#        'other_player_dismissed'],
#       dtype='object')

# %%
relevantColumns = ['match_id', 'venue', 'innings', 'ball', 'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler','runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes','penalty']

# %%
ipl_data = ipl_data[relevantColumns]

# %%
#create another column that tells number of runs scored, including off the bat and
#extra runs conceded by bowling team
ipl_data['total_runs'] = ipl_data['runs_off_bat'] + ipl_data['extras']
ipl_data
# Out:
# <ipython-input-102-a6565127c449>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_data['total_runs'] = ipl_data['runs_off_bat'] + ipl_data['extras']
#         match_id                                     venue  innings  ball  \
# 0         335982                     M Chinnaswamy Stadium        1   0.1
# 1         335982                     M Chinnaswamy Stadium        1   0.2
# 2         335982                     M Chinnaswamy Stadium        1   0.3
# 3         335982                     M Chinnaswamy Stadium        1   0.4
# 4         335982                     M Chinnaswamy Stadium        1   0.5
# ...          ...                                       ...      ...   ...
# 196795   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2  18.6
# 196796   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2  18.7
# 196797   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2  18.8
# 196798   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2  19.1
# 196799   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2  19.2
#
#                  batting_team                 bowling_team      striker  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# ...                       ...                          ...          ...
# 196795         Delhi Capitals               Mumbai Indians  Lalit Yadav
# 196796         Delhi Capitals               Mumbai Indians   SO Hetmyer
# 196797         Delhi Capitals               Mumbai Indians   SO Hetmyer
# 196798         Delhi Capitals               Mumbai Indians   SO Hetmyer
# 196799         Delhi Capitals               Mumbai Indians   SO Hetmyer
#
#         non_striker      bowler  runs_off_bat  extras  wides  noballs  byes  \
# 0       BB McCullum     P Kumar             0       1    NaN      NaN   NaN
# 1        SC Ganguly     P Kumar             0       0    NaN      NaN   NaN
# 2        SC Ganguly     P Kumar             0       1    1.0      NaN   NaN
# 3        SC Ganguly     P Kumar             0       0    NaN      NaN   NaN
# 4        SC Ganguly     P Kumar             0       0    NaN      NaN   NaN
# ...             ...         ...           ...     ...    ...      ...   ...
# 196795   SO Hetmyer   JJ Bumrah             1       0    NaN      NaN   NaN
# 196796  Lalit Yadav   JJ Bumrah             2       0    NaN      NaN   NaN
# 196797  Lalit Yadav   JJ Bumrah             1       0    NaN      NaN   NaN
# 196798  Lalit Yadav  KA Pollard             4       0    NaN      NaN   NaN
# 196799  Lalit Yadav  KA Pollard             0       1    NaN      1.0   NaN
#
#         legbyes  penalty  total_runs
# 0           1.0      NaN           1
# 1           NaN      NaN           0
# 2           NaN      NaN           1
# 3           NaN      NaN           0
# 4           NaN      NaN           0
# ...         ...      ...         ...
# 196795      NaN      NaN           1
# 196796      NaN      NaN           2
# 196797      NaN      NaN           1
# 196798      NaN      NaN           4
# 196799      NaN      NaN           1
#
# [196800 rows x 17 columns]

# %%
#now drop the columns runs_off_bat and extras as they are not required anymore
ipl_data = ipl_data.drop(columns=['runs_off_bat','extras'])
ipl_data
# Out:
#         match_id                                     venue  innings  ball  \
# 0         335982                     M Chinnaswamy Stadium        1   0.1
# 1         335982                     M Chinnaswamy Stadium        1   0.2
# 2         335982                     M Chinnaswamy Stadium        1   0.3
# 3         335982                     M Chinnaswamy Stadium        1   0.4
# 4         335982                     M Chinnaswamy Stadium        1   0.5
# ...          ...                                       ...      ...   ...
# 196795   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2  18.6
# 196796   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2  18.7
# 196797   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2  18.8
# 196798   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2  19.1
# 196799   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2  19.2
#
#                  batting_team                 bowling_team      striker  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# ...                       ...                          ...          ...
# 196795         Delhi Capitals               Mumbai Indians  Lalit Yadav
# 196796         Delhi Capitals               Mumbai Indians   SO Hetmyer
# 196797         Delhi Capitals               Mumbai Indians   SO Hetmyer
# 196798         Delhi Capitals               Mumbai Indians   SO Hetmyer
# 196799         Delhi Capitals               Mumbai Indians   SO Hetmyer
#
#         non_striker      bowler  wides  noballs  byes  legbyes  penalty  \
# 0       BB McCullum     P Kumar    NaN      NaN   NaN      1.0      NaN
# 1        SC Ganguly     P Kumar    NaN      NaN   NaN      NaN      NaN
# 2        SC Ganguly     P Kumar    1.0      NaN   NaN      NaN      NaN
# 3        SC Ganguly     P Kumar    NaN      NaN   NaN      NaN      NaN
# 4        SC Ganguly     P Kumar    NaN      NaN   NaN      NaN      NaN
# ...             ...         ...    ...      ...   ...      ...      ...
# 196795   SO Hetmyer   JJ Bumrah    NaN      NaN   NaN      NaN      NaN
# 196796  Lalit Yadav   JJ Bumrah    NaN      NaN   NaN      NaN      NaN
# 196797  Lalit Yadav   JJ Bumrah    NaN      NaN   NaN      NaN      NaN
# 196798  Lalit Yadav  KA Pollard    NaN      NaN   NaN      NaN      NaN
# 196799  Lalit Yadav  KA Pollard    NaN      1.0   NaN      NaN      NaN
#
#         total_runs
# 0                1
# 1                0
# 2                1
# 3                0
# 4                0
# ...            ...
# 196795           1
# 196796           2
# 196797           1
# 196798           4
# 196799           1
#
# [196800 rows x 15 columns]

# %%
#only select the rows belonging to first 6 overs
ipl_data = ipl_data[ipl_data['ball'] <= 5.6]
ipl_data
# Out:
#         match_id                                     venue  innings  ball  \
# 0         335982                     M Chinnaswamy Stadium        1   0.1
# 1         335982                     M Chinnaswamy Stadium        1   0.2
# 2         335982                     M Chinnaswamy Stadium        1   0.3
# 3         335982                     M Chinnaswamy Stadium        1   0.4
# 4         335982                     M Chinnaswamy Stadium        1   0.5
# ...          ...                                       ...      ...   ...
# 196711   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2   5.2
# 196712   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2   5.3
# 196713   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2   5.4
# 196714   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2   5.5
# 196715   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2   5.6
#
#                  batting_team                 bowling_team      striker  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# ...                       ...                          ...          ...
# 196711         Delhi Capitals               Mumbai Indians     S Dhawan
# 196712         Delhi Capitals               Mumbai Indians    SPD Smith
# 196713         Delhi Capitals               Mumbai Indians     S Dhawan
# 196714         Delhi Capitals               Mumbai Indians     S Dhawan
# 196715         Delhi Capitals               Mumbai Indians    SPD Smith
#
#         non_striker     bowler  wides  noballs  byes  legbyes  penalty  \
# 0       BB McCullum    P Kumar    NaN      NaN   NaN      1.0      NaN
# 1        SC Ganguly    P Kumar    NaN      NaN   NaN      NaN      NaN
# 2        SC Ganguly    P Kumar    1.0      NaN   NaN      NaN      NaN
# 3        SC Ganguly    P Kumar    NaN      NaN   NaN      NaN      NaN
# 4        SC Ganguly    P Kumar    NaN      NaN   NaN      NaN      NaN
# ...             ...        ...    ...      ...   ...      ...      ...
# 196711    SPD Smith  KH Pandya    NaN      NaN   NaN      NaN      NaN
# 196712     S Dhawan  KH Pandya    NaN      NaN   NaN      NaN      NaN
# 196713    SPD Smith  KH Pandya    NaN      NaN   NaN      NaN      NaN
# 196714    SPD Smith  KH Pandya    NaN      NaN   NaN      NaN      NaN
# 196715     S Dhawan  KH Pandya    NaN      NaN   NaN      NaN      NaN
#
#         total_runs
# 0                1
# 1                0
# 2                1
# 3                0
# 4                0
# ...            ...
# 196711           1
# 196712           1
# 196713           0
# 196714           1
# 196715           1
#
# [61720 rows x 15 columns]

# %%
ipl_data = ipl_data[ipl_data['innings'] <= 2]
ipl_data
# Out:
#         match_id                                     venue  innings  ball  \
# 0         335982                     M Chinnaswamy Stadium        1   0.1
# 1         335982                     M Chinnaswamy Stadium        1   0.2
# 2         335982                     M Chinnaswamy Stadium        1   0.3
# 3         335982                     M Chinnaswamy Stadium        1   0.4
# 4         335982                     M Chinnaswamy Stadium        1   0.5
# ...          ...                                       ...      ...   ...
# 196711   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2   5.2
# 196712   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2   5.3
# 196713   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2   5.4
# 196714   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2   5.5
# 196715   1254070  MA Chidambaram Stadium, Chepauk, Chennai        2   5.6
#
#                  batting_team                 bowling_team      striker  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# 1       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 2       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 3       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# 4       Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum
# ...                       ...                          ...          ...
# 196711         Delhi Capitals               Mumbai Indians     S Dhawan
# 196712         Delhi Capitals               Mumbai Indians    SPD Smith
# 196713         Delhi Capitals               Mumbai Indians     S Dhawan
# 196714         Delhi Capitals               Mumbai Indians     S Dhawan
# 196715         Delhi Capitals               Mumbai Indians    SPD Smith
#
#         non_striker     bowler  wides  noballs  byes  legbyes  penalty  \
# 0       BB McCullum    P Kumar    NaN      NaN   NaN      1.0      NaN
# 1        SC Ganguly    P Kumar    NaN      NaN   NaN      NaN      NaN
# 2        SC Ganguly    P Kumar    1.0      NaN   NaN      NaN      NaN
# 3        SC Ganguly    P Kumar    NaN      NaN   NaN      NaN      NaN
# 4        SC Ganguly    P Kumar    NaN      NaN   NaN      NaN      NaN
# ...             ...        ...    ...      ...   ...      ...      ...
# 196711    SPD Smith  KH Pandya    NaN      NaN   NaN      NaN      NaN
# 196712     S Dhawan  KH Pandya    NaN      NaN   NaN      NaN      NaN
# 196713    SPD Smith  KH Pandya    NaN      NaN   NaN      NaN      NaN
# 196714    SPD Smith  KH Pandya    NaN      NaN   NaN      NaN      NaN
# 196715     S Dhawan  KH Pandya    NaN      NaN   NaN      NaN      NaN
#
#         total_runs
# 0                1
# 1                0
# 2                1
# 3                0
# 4                0
# ...            ...
# 196711           1
# 196712           1
# 196713           0
# 196714           1
# 196715           1
#
# [61571 rows x 15 columns]

# %%
#preprocess the data so that we get a tuple of following kind in each row:
    # ('match_id', 'venue', 'innings', 'batting_team', 'bowling_team', 'total_runs')

ipl_data = ipl_data.groupby(['match_id', 'venue', 'innings', 'batting_team', 'bowling_team' ]).total_runs.sum()
ipl_data
# Out:
# match_id  venue                                       innings  batting_team                 bowling_team
# 335982    M Chinnaswamy Stadium                       1        Kolkata Knight Riders        Royal Challengers Bangalore    61
#                                                       2        Royal Challengers Bangalore  Kolkata Knight Riders          26
# 335983    Punjab Cricket Association Stadium, Mohali  1        Chennai Super Kings          Kings XI Punjab                53
#                                                       2        Kings XI Punjab              Chennai Super Kings            56
# 335984    Feroz Shah Kotla                            1        Rajasthan Royals             Delhi Daredevils               40
#                                                                                                                            ..
# 1254068   Wankhede Stadium, Mumbai                    2        Delhi Capitals               Punjab Kings                   62
# 1254069   Wankhede Stadium, Mumbai                    1        Chennai Super Kings          Rajasthan Royals               46
#                                                       2        Rajasthan Royals             Chennai Super Kings            45
# 1254070   MA Chidambaram Stadium, Chepauk, Chennai    1        Mumbai Indians               Delhi Capitals                 55
#                                                       2        Delhi Capitals               Mumbai Indians                 39
# Name: total_runs, Length: 1656, dtype: int64

# %%
#convert back to data frame
ipl_data = ipl_data.reset_index()
ipl_data
# Out:
#       match_id                                       venue  innings  \
# 0       335982                       M Chinnaswamy Stadium        1
# 1       335982                       M Chinnaswamy Stadium        2
# 2       335983  Punjab Cricket Association Stadium, Mohali        1
# 3       335983  Punjab Cricket Association Stadium, Mohali        2
# 4       335984                            Feroz Shah Kotla        1
# ...        ...                                         ...      ...
# 1651   1254068                    Wankhede Stadium, Mumbai        2
# 1652   1254069                    Wankhede Stadium, Mumbai        1
# 1653   1254069                    Wankhede Stadium, Mumbai        2
# 1654   1254070    MA Chidambaram Stadium, Chepauk, Chennai        1
# 1655   1254070    MA Chidambaram Stadium, Chepauk, Chennai        2
#
#                      batting_team                 bowling_team  total_runs
# 0           Kolkata Knight Riders  Royal Challengers Bangalore          61
# 1     Royal Challengers Bangalore        Kolkata Knight Riders          26
# 2             Chennai Super Kings              Kings XI Punjab          53
# 3                 Kings XI Punjab          Chennai Super Kings          56
# 4                Rajasthan Royals             Delhi Daredevils          40
# ...                           ...                          ...         ...
# 1651               Delhi Capitals                 Punjab Kings          62
# 1652          Chennai Super Kings             Rajasthan Royals          46
# 1653             Rajasthan Royals          Chennai Super Kings          45
# 1654               Mumbai Indians               Delhi Capitals          55
# 1655               Delhi Capitals               Mumbai Indians          39
#
# [1656 rows x 6 columns]

# %%
#no need of match_id
ipl_data = ipl_data.drop(columns=['match_id'])
ipl_data
# Out:
#                                            venue  innings  \
# 0                          M Chinnaswamy Stadium        1
# 1                          M Chinnaswamy Stadium        2
# 2     Punjab Cricket Association Stadium, Mohali        1
# 3     Punjab Cricket Association Stadium, Mohali        2
# 4                               Feroz Shah Kotla        1
# ...                                          ...      ...
# 1651                    Wankhede Stadium, Mumbai        2
# 1652                    Wankhede Stadium, Mumbai        1
# 1653                    Wankhede Stadium, Mumbai        2
# 1654    MA Chidambaram Stadium, Chepauk, Chennai        1
# 1655    MA Chidambaram Stadium, Chepauk, Chennai        2
#
#                      batting_team                 bowling_team  total_runs
# 0           Kolkata Knight Riders  Royal Challengers Bangalore          61
# 1     Royal Challengers Bangalore        Kolkata Knight Riders          26
# 2             Chennai Super Kings              Kings XI Punjab          53
# 3                 Kings XI Punjab          Chennai Super Kings          56
# 4                Rajasthan Royals             Delhi Daredevils          40
# ...                           ...                          ...         ...
# 1651               Delhi Capitals                 Punjab Kings          62
# 1652          Chennai Super Kings             Rajasthan Royals          46
# 1653             Rajasthan Royals          Chennai Super Kings          45
# 1654               Mumbai Indians               Delhi Capitals          55
# 1655               Delhi Capitals               Mumbai Indians          39
#
# [1656 rows x 5 columns]

# %%
ipl_data['batting_team'] = ipl_data['batting_team'].replace(['Kings XI Punjab'],'Punjab Kings')
ipl_data['bowling_team'] = ipl_data['bowling_team'].replace(['Kings XI Punjab'],'Punjab Kings')
ipl_data['bowling_team'] = ipl_data['bowling_team'].replace(['Delhi Daredevils'],'Delhi Capitals')
ipl_data['batting_team'] = ipl_data['batting_team'].replace(['Delhi Daredevils'],'Delhi Capitals')

# %%
ipl_data['venue'] = ipl_data['venue'].replace(['M Chinnaswamy Stadium'],'M.Chinnaswamy Stadium')
ipl_data['venue'] = ipl_data['venue'].replace(['Rajiv Gandhi International Stadium, Uppal'],'Rajiv Gandhi International Stadium')
ipl_data['venue'] = ipl_data['venue'].replace(['Sardar Patel Stadium, Moter'],'Narendra Modi Stadium')
ipl_data['venue'] = ipl_data['venue'].replace(['Punjab Cricket Association IS Bindra Stadium, Mohali'],'Punjab Cricket Association IS Bindra Stadium')
ipl_data['venue'] = ipl_data['venue'].replace(['Punjab Cricket Association Stadium, Mohali'],'Punjab Cricket Association IS Bindra Stadium')
ipl_data['venue'] = ipl_data['venue'].replace(['Wankhede Stadium, Mumbai'],'Wankhede Stadium')
ipl_data['venue'] = ipl_data['venue'].replace(['Feroz Shah Kotla'],'Arun Jaitley Stadium')
ipl_data['venue'] = ipl_data['venue'].replace(['MA Chidambaram Stadium, Chepauk, Chennai'],'MA Chidambaram Stadium')
ipl_data['venue'] = ipl_data['venue'].replace(['MA Chidambaram Stadium, Chepauk'],'MA Chidambaram Stadium')

# %%
ipl_data
# Out:
#                                              venue  innings  \
# 0                            M.Chinnaswamy Stadium        1
# 1                            M.Chinnaswamy Stadium        2
# 2     Punjab Cricket Association IS Bindra Stadium        1
# 3     Punjab Cricket Association IS Bindra Stadium        2
# 4                             Arun Jaitley Stadium        1
# ...                                            ...      ...
# 1651                              Wankhede Stadium        2
# 1652                              Wankhede Stadium        1
# 1653                              Wankhede Stadium        2
# 1654                        MA Chidambaram Stadium        1
# 1655                        MA Chidambaram Stadium        2
#
#                      batting_team                 bowling_team  total_runs
# 0           Kolkata Knight Riders  Royal Challengers Bangalore          61
# 1     Royal Challengers Bangalore        Kolkata Knight Riders          26
# 2             Chennai Super Kings                 Punjab Kings          53
# 3                    Punjab Kings          Chennai Super Kings          56
# 4                Rajasthan Royals               Delhi Capitals          40
# ...                           ...                          ...         ...
# 1651               Delhi Capitals                 Punjab Kings          62
# 1652          Chennai Super Kings             Rajasthan Royals          46
# 1653             Rajasthan Royals          Chennai Super Kings          45
# 1654               Mumbai Indians               Delhi Capitals          55
# 1655               Delhi Capitals               Mumbai Indians          39
#
# [1656 rows x 5 columns]

# %%
ipl_data.to_csv("Preprocessed.csv", index=False)
